# %% [markdown]
# ### Assignment 2: Develop a MapReduce program to calculate the frequency of a given word in a given file.

# %% [markdown]
# ### Step 1: Install Dependencies

# %%
# !pip install mrjob

# %%
# !python word_count.py
# Out:
# "ai."	1
# "amazing."	1
# "and"	1
# "data!"	1
# "data"	2
# "data,"	2
# "future"	1
# "is"	2
# "more"	1
# "of"	1
# "science"	1
# "the"	1
# No configs found; falling back on auto-configuration
# No configs specified for inline runner
# Creating temp directory C:\Users\Victus\AppData\Local\Temp\word_count.Victus.20250227.055724.776699
# Running step 1 of 1...
# job output is in C:\Users\Victus\AppData\Local\Temp\word_count.Victus.20250227.055724.776699\output
# Streaming final output from C:\Users\Victus\AppData\Local\Temp\word_count.Victus.20250227.055724.776699\output...
# Removing temp directory C:\Users\Victus\AppData\Local\Temp\word_count.Victus.20250227.055724.776699...
